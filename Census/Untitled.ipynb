# %%
import pandas as pd

from sklearn.decomposition import PCA

# Plotly
import seaborn as sns

# %%
X = pd.DataFrame(PCA(n_components=2).fit_transform(pd.read_csv("datasets/test_ohe_pca.csv")), columns=["PCA1", "PCA2"])
y = pd.read_csv("datasets/test_ohe_pca_y.csv")

# %%
sns.scatterplot(x=X.PCA1, y=X.PCA2, hue=y["0"])

# %%
# Out:
#        0
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 24388  1
# 24389  0
# 24390  0
# 24391  0
# 24392  1
#
# [24393 rows x 1 columns]
